# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import date, datetime, timedelta

import sys
sys.path.append("..")
import scripts.utils as sskt_utils

# %%
date0 = datetime(2023, 12, 25)
date1 = datetime(2024, 1, 1)

print(sskt_utils.dcf(date0,date1))
# Out:
# 0.019444444444444445

# %%
import sys
print(sys.executable)
# Out:
# /Users/alejandro/Documents/Git/SSKT/venv/bin/python

# %%
x = np.linspace(0,1,11)
print(x)
